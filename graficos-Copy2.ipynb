# %% [markdown]
# ## **<font color='darkblue'>Gráficos</font>**

# %% [markdown]
# ### **<font color='purple'>Bibliotecas</font>**

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ### **<font color='purple'>Leitura da base de dados</font>**

# %%
df = pd.read_csv('dados/VC_ST_dia.csv', sep=';', index_col='data')
df.head()
# Out:
#             acessos
# data
# 01/06/2022       74
# 02/06/2022      129
# 03/06/2022      189
# 04/06/2022      196
# 05/06/2022       74

# %% [markdown]
# ### **<font color='purple'>Transformações na coluna de data</font>**

# %%
df.index = pd.to_datetime(df.index, format='%d/%m/%Y')
df.index
# Out:
# DatetimeIndex(['2022-06-01', '2022-06-02', '2022-06-03', '2022-06-04',
#                '2022-06-05', '2022-06-06', '2022-06-07', '2022-06-08',
#                '2022-06-09', '2022-06-10',
#                ...
#                '2023-02-19', '2023-02-20', '2023-02-21', '2023-02-22',
#                '2023-02-23', '2023-02-24', '2023-02-25', '2023-02-26',
#                '2023-02-27', '2023-02-28'],
#               dtype='datetime64[ns]', name='data', length=273, freq=None)

# %% [markdown]
# ### **<font color='purple'>Visualização da série temporal</font>**

# %%
df.plot(figsize=(8,5))
# Out:
# <AxesSubplot:xlabel='data'>

# %%
h1 = df['acessos'].plot.hist(bins=50)

# %%
d1 = df['acessos'].plot.density()

# %%
sns.distplot(a=df.acessos, kde=False)
plt.show()
# Out:
# C:\Users\mfran\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(a=df.acessos, hist=False)
plt.show()
# Out:
# C:\Users\mfran\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(a=df.acessos)
plt.show()
# Out:
# C:\Users\mfran\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure()

ax = fig.add_subplot(1,1,1)

df.plot(ax=ax, style='k-')

outliers = [
    (datetime(2022, 7, 11), 'Absolutely no idea'),
    (datetime(2022, 10, 15), 'Acessos post AJ')
]

for date, label in outliers:
    ax.annotate(label, xy=(date, df.asof(date) + 300),
                xytext = (date, df.asof(date) + 825),
                arrowprops=dict(facecolor='blue', headwidth=4, width=2, 
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

    ax.set_xlim(['1/1/2022', '31/12/2022'])
    ax.set_ylim([10, 1500])
    ax.set_title('Dias com possíveis outliers')
# Out:
# C:\Users\mfran\anaconda3\lib\site-packages\matplotlib\axis.py:1506: UserWarning: Parsing '31/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   ret = self.converter.convert(x, self.units, self)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
plt.plot(np.random.random(50).cumsum(),'g--')
ax1.hist(np.random.random(100), bins = 20, color = 'g', alpha = 0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30), color = "orangered")
ax3.scatter(np.arange(50), np.arange(50) + 3 * np.random.randn(50))

# %%
plt.plot(randn(30).cumsum(), 'ko--')

# %%
plt.plot(df, 'g--', label='Viagem Cinema')
plt.plot(df, 'k-', drawstyle='steps-post', label='Viagem 2')
plt.legend(loc='best')
plt.title('Living and learning')
plt.ylabel('Qty', color='red')
plt.xlabel('Months', color='blue')
# Out:
# Text(0.5, 0, 'Months')

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_title('Living and learning')
ax.set_xlabel('Outcomes')
# Out:
# Text(0.5, 0, 'Outcomes')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum(), 'k', label='one', alpha=0.5)
ax.plot(np.random.randn(1000).cumsum(), 'g.', label='two', alpha=0.5)
ax.plot(np.random.randn(1000).cumsum(), 'b--.', label='thrree', alpha=0.5)
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=50, fontsize='small')
ax.set_title('Living and learning')
ax.set_ylabel('Numbers', color='red')
ax.set_xlabel('Outcomes', color='blue')
ax.legend(loc='best')

# %%
df_s = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                    columns=['A', 'B', 'C', 'D'],
                    index= np.arange(0, 100, 10))

df_s.plot()
# Out:
# <AxesSubplot:>

# %%
fig, axes= plt.subplots(2,1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0], color='k', alpha=0.6)
data.plot.barh(ax=axes[1], color='k', alpha=0.7)
# Out:
# <AxesSubplot:>
